# %%
import IPython
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('/content/Crop_recommendation.csv')

# %%
data.head(5) #first five
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
data.tail(5) #last five
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
data.shape
# Out:
# (2200, 8)

# %%
data.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
data.duplicated().sum() #data.drop_duplicates()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
data.nunique()
# Out:
# N               137
# P               117
# K                73
# temperature    2200
# humidity       2200
# ph             2200
# rainfall       2200
# label            22
# dtype: int64

# %%
data['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
data['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
crop_summary=pd.pivot_table(data,index=['label'],aggfunc='mean')

# %%
crop_summary
# Out:
#                   K       N       P   humidity        ph    rainfall  \
# label
# apple        199.89   20.80  134.22  92.333383  5.929663  112.654779
# banana        50.05  100.23   82.01  80.358123  5.983893  104.626980
# blackgram     19.24   40.02   67.47  65.118426  7.133952   67.884151
# chickpea      79.92   40.09   67.79  16.860439  7.336957   80.058977
# coconut       30.59   21.98   16.93  94.844272  5.976562  175.686646
# coffee        29.94  101.20   28.74  58.869846  6.790308  158.066295
# cotton        19.56  117.77   46.24  79.843474  6.912675   80.398043
# grapes       200.11   23.18  132.53  81.875228  6.025937   69.611829
# jute          39.99   78.40   46.86  79.639864  6.732778  174.792798
# kidneybeans   20.05   20.75   67.54  21.605357  5.749411  105.919778
# lentil        19.41   18.77   68.36  64.804785  6.927932   45.680454
# maize         19.79   77.76   48.44  65.092249  6.245190   84.766988
# ...

# %%
data.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
import plotly.express as px

# %%
# checking and treating outliers in each column

# %%
fig=px.box(data,y="N",points='all')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(data,y="P",points='all')
# sns.boxplot(data(i))
 #plt.xticks(rotation=90)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(data,y="K",points='all')
# sns.boxplot(data1(i))
 #plt.xticks(rotation=90)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(data, y='temperature', points='all')
# sns.boxplot(data1(i))
 #plt.xticks(rotation=90)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(data, y='humidity', points='all')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
fig=px.box(data, y='ph', points='all')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(data, y='rainfall', points='all')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#you can detect outliers and remove outliers

# %%
df_boston=data
df_boston.columns=df_boston.columns
df_boston.head()
''' Detection'''
#IQR
Q1=np.percentile(df_boston['rainfall'],25,interpolation='midpoint')
Q3=np.percentile(df_boston['rainfall'],75,interpolation='midpoint')
IQR=Q3-Q1
print("Old Shape:", df_boston.shape)

#Upper bound
upper=np.where(df_boston['rainfall']>= (Q3+1.5*IQR))
#Lower bound
lower=np.where(df_boston['rainfall']<= (Q1-1.5*IQR))

''' Removing the Outliers '''
df_boston.drop(upper[0], inplace = True)
df_boston.drop(lower[0], inplace = True)
print("New Shape:", df_boston.shape)
# Out:
# Old Shape: (2200, 8)
# New Shape: (2101, 8)

# %%
df_boston=data
df_boston.columns=df_boston.columns
df_boston.head()
''' Detection'''
#IQR
Q1=np.percentile(df_boston['ph'],25,interpolation='midpoint')
Q3=np.percentile(df_boston['ph'],75,interpolation='midpoint')
IQR=Q3-Q1
print("Old Shape:", df_boston.shape)

#Upper bound
upper=np.where(df_boston['ph']>= (Q3+1.5*IQR))
#Lower bound
lower=np.where(df_boston['ph']<= (Q1-1.5*IQR))

''' Removing the Outliers '''
df_boston.drop(upper[0], inplace = True)
df_boston.drop(lower[0], inplace = True)
print("New Shape:", df_boston.shape)
# Out:
# Old Shape: (2101, 8)
# New Shape: (2042, 8)

# %%
df_boston=data
df_boston.columns=df_boston.columns
df_boston.head()
''' Detection'''
#IQR
Q1=np.percentile(df_boston['humidity'],25,interpolation='midpoint')
Q3=np.percentile(df_boston['humidity'],75,interpolation='midpoint')
IQR=Q3-Q1
print("Old Shape:", df_boston.shape)

# Filtering out the outliers instead of dropping by index
# Keep rows where 'humidity' is within the defined bounds
df_boston = df_boston[~((df_boston['humidity'] < (Q1 - 1.5 * IQR)) | (df_boston['humidity'] > (Q3 + 1.5 * IQR)))]

print("New Shape:", df_boston.shape)
# Out:
# Old Shape: (2042, 8)
# New Shape: (2007, 8)

# %%
df_boston=data
df_boston.columns=df_boston.columns
df_boston.head()
''' Detection'''
#IQR
Q1=np.percentile(df_boston['K'],25,interpolation='midpoint')
Q3=np.percentile(df_boston['K'],75,interpolation='midpoint')
IQR=Q3-Q1
print("Old Shape:", df_boston.shape)

# Filtering out the outliers instead of dropping by index
# Keep rows where 'humidity' is within the defined bounds
df_boston = df_boston[~((df_boston['K'] < (Q1 - 1.5 * IQR)) | (df_boston['K'] > (Q3 + 1.5 * IQR)))]

print("New Shape:", df_boston.shape)
# Out:
# Old Shape: (2042, 8)
# New Shape: (1842, 8)

# %%
data=df_boston

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='N',x='label',data=data,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='P',x='label',data=data,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='K',x='label',data=data,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='temperature',x='label',data=data,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='humidity',x='label',data=data,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='ph',x='label',data=data,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(y='rainfall',x='label',data=data,palette='hls')
plt.xticks(rotation=90)
plt.show()

# %%
#pip install plotly

# %%
crop_summary_new=data.copy()

# %%
import plotly.graph_objects as go4
import plotly.express as px
from plotly.subplots import make_subplots

# %%
fig1=px.bar(crop_summary_new, x='label', y='N', title='N')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1=px.bar(crop_summary_new,x='label',y='P')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1=px.bar(crop_summary_new,x='label',y='K')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1=px.bar(crop_summary_new,x='label',y='temperature')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1=px.bar(crop_summary_new,x='label',y='humidity')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1=px.bar(crop_summary_new,x='label',y='ph')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1=px.bar(crop_summary_new,x='label',y='rainfall')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import random
from IPython.core.display import update_display

# %%
data.drop('label', axis=1).corr()
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.072876  0.294301     0.014023  0.252293  0.044519
# P           -0.072876  1.000000  0.041282    -0.031416 -0.472219  0.038800
# K            0.294301  0.041282  1.000000    -0.066528 -0.089384  0.055990
# temperature  0.014023 -0.031416 -0.066528     1.000000  0.292827 -0.053073
# humidity     0.252293 -0.472219 -0.089384     0.292827  1.000000  0.038882
# ph           0.044519  0.038800  0.055990    -0.053073  0.038882  1.000000
# rainfall     0.000250 -0.044572 -0.010615    -0.049258  0.028323 -0.136974
#
#              rainfall
# N            0.000250
# P           -0.044572
# K           -0.010615
# temperature -0.049258
# humidity     0.028323
# ph          -0.136974
# rainfall     1.000000

# %%
fig,ax=plt.subplots(1,1,figsize=(15,9))
sns.heatmap(data.drop('label', axis=1).corr(),annot=True,cmap='Wistia')
ax.set(xlabel='features')
ax.set(ylabel='features')

plt.title('correlation between different features', fontsize=15,c='black')
plt.show()

# %%
x=data.drop('label',axis=1)
y=data['label']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,shuffle=True,random_state=0)

# %%
import lightgbm as lgb
model=lgb.LGBMClassifier(verbose=-1) # Add verbose=-1 to suppress warnings
model.fit(x_train,y_train)
# Out:
# LGBMClassifier(verbose=-1)

# %%
Y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
Y_pred = model.predict(x_test)
accuracy=accuracy_score(y_pred=Y_pred,y_true=y_test)
print('LightGBM Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test,Y_pred)))
# Out:
# LightGBM Model accuracy score: 0.9873

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,Y_pred)

plt.figure(figsize=(15,15))
sns.heatmap(cm,annot=True,fmt="0f",linewidth=5,square=True,cmap='Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title='Confusion Matrix - score:' + str(accuracy_score(y_test,Y_pred))
plt.title(all_sample_title, size=15);
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       banana       1.00      1.00      1.00        28
#    blackgram       0.94      1.00      0.97        30
#     chickpea       1.00      1.00      1.00        32
#      coconut       1.00      1.00      1.00        20
#       coffee       1.00      1.00      1.00        26
#       cotton       1.00      1.00      1.00        30
#         jute       0.88      1.00      0.94        30
#  kidneybeans       0.97      1.00      0.98        32
#       lentil       1.00      1.00      1.00        29
#        maize       1.00      1.00      1.00        27
#        mango       1.00      1.00      1.00        34
#    mothbeans       1.00      0.96      0.98        26
#     mungbean       1.00      1.00      1.00        39
#    muskmelon       1.00      1.00      1.00        30
#       orange       1.00      1.00      1.00        33
#       papaya       1.00      1.00      1.00        25
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
Classifier=DecisionTreeClassifier(criterion='entropy',random_state=0)
Classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred=Classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print('Decision Tree Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test,y_pred)))
# Out:
# Decision Tree Model accuracy score: 0.9873

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

plt.figure(figsize=(15,15))
sns.heatmap(cm,annot=True,fmt="0f",linewidth=5,square=True,cmap='Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title='Confusion Matrix - score:' + str(accuracy_score(y_test,y_pred))
plt.title(all_sample_title,size=15);
plt.show()

# %%
from  sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       banana       1.00      1.00      1.00        28
#    blackgram       0.94      0.97      0.95        30
#     chickpea       1.00      1.00      1.00        32
#      coconut       1.00      1.00      1.00        20
#       coffee       1.00      1.00      1.00        26
#       cotton       1.00      1.00      1.00        30
#         jute       0.93      0.93      0.93        30
#  kidneybeans       1.00      1.00      1.00        32
#       lentil       1.00      1.00      1.00        29
#        maize       0.96      1.00      0.98        27
#        mango       1.00      1.00      1.00        34
#    mothbeans       1.00      0.92      0.96        26
#     mungbean       1.00      1.00      1.00        39
#    muskmelon       1.00      1.00      1.00        30
#       orange       1.00      1.00      1.00        33
#       papaya       1.00      1.00      1.00        25
# ...

# %%
x_test[0:1]
# Out:
#         N   P   K  temperature   humidity        ph   rainfall
# 1964  119  44  15    22.145937  82.859755  7.091992  60.653817

# %%
result=Classifier.predict(x_test[0:1])

# %%
result
# Out:
# array(['cotton'], dtype=object)

# %%
y_test[0:1]
# Out:
# 1964    cotton
# Name: label, dtype: object
